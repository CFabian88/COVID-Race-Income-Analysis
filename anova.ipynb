# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
os.chdir('/Users/fabian_coll/Desktop/PyProjects/COVID-Race-Income-Analysis/data/clean')

# %%
df = pd.read_csv('COVID_deaths.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#   State                  County                            Indicator  \
# 0    AK  Anchorage Municipality  Distribution of COVID-19 deaths (%)
# 1    AL          Baldwin County  Distribution of COVID-19 deaths (%)
# 2    AL          Calhoun County  Distribution of COVID-19 deaths (%)
# 3    AL          Colbert County  Distribution of COVID-19 deaths (%)
# 4    AL          Cullman County  Distribution of COVID-19 deaths (%)
#
#    TotalDeaths  COVID-19 Deaths  White  Black  AmericanIndian/NativeIslander  \
# 0         2624              180  0.317    NaN                          0.339
# 1         2757              234  0.859  0.115                            NaN
# 2         1972              267  0.798  0.191                            NaN
# 3          885              160  0.788  0.162                            NaN
# 4         1422              202  0.975    NaN                            NaN
#
#    Asian  NativeHawaiian/PacificIslander  ...  \
# ...

# %%
# Look at # of Missing data points per race
races = ['White', 'Black', 'AmericanIndian/NativeIslander', 'Asian', 'NativeHawaiian/PacificIslander', 'Hispanic', 'Other']
xlabels = ['White', 'Black', 'AIndian/NIslander', 'Asian', 'NHawaiian/PIslander', 'Hispanic', 'Other']
race_num_missingVals = []
for i in races:
    rowName = str(i+'_per100k')
    race_num_missingVals.append(df[rowName].isna().sum())

plt.bar(xlabels, race_num_missingVals)
plt.title('# Missing Data Points by Race (out of 723)')
plt.xlabel('Race')
plt.ylabel('# Data Points')
plt.xticks(rotation = 60)
plt.show()
